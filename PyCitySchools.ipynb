# %%
# Add the Pandas dependency.
import pandas as pd
import os
import numpy as np

# %%
# Files to load
school_data_to_load = os.path.join("Resources","Schools_Complete.csv")
student_data_to_load = os.path.join("Resources","Students_Complete.csv")

# %%
# Read the school data file and store it in a Pandas DataFrame.
school_data_df = pd.read_csv(school_data_to_load)
school_data_df
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
# Read the student data file and store it in a Pandas DataFrame.
student_data_df = pd.read_csv(student_data_to_load)
student_data_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
#school data rows and columns 
school_data_df.shape
# Out:
# (15, 5)

# %%
#student data rows and columns
student_data_df.shape
# Out:
# (39170, 7)

# %% [markdown]
# # PRE WORK

# %%
#school_data summary
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   School ID    15 non-null     int64
#  1   school_name  15 non-null     object
#  2   type         15 non-null     object
#  3   size         15 non-null     int64
#  4   budget       15 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 728.0+ bytes

# %%
#student_ data summary
student_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39170 entries, 0 to 39169
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 2.1+ MB

# %%
#The average math score for each grade level from each school
student_data_df.groupby(['school_name','grade'])['math_score'].mean().unstack()
# Out:
# grade                       10th       11th       12th        9th
# school_name
# Bailey High School     76.996772  77.515588  76.492218  77.083676
# Cabrera High School    83.154506  82.765560  83.277487  83.094697
# Figueroa High School   76.539974  76.884344  77.151369  76.403037
# Ford High School       77.672316  76.918058  76.179963  77.361345
# Griffin High School    84.229064  83.842105  83.356164  82.044010
# Hernandez High School  77.337408  77.136029  77.186567  77.438495
# Holden High School     83.429825  85.000000  82.855422  83.787402
# Huang High School      75.908735  76.446602  77.225641  77.027251
# Johnson High School    76.691117  77.491653  76.863248  77.187857
# Pena High School       83.372000  84.328125  84.121547  83.625455
# Rodriguez High School  76.612500  76.395626  77.690748  76.859966
# Shelton High School    82.917411  83.383495  83.778976  83.420755
# Thomas High School     83.087886  83.498795  83.497041  83.590022
# ...

# %%
#The average reading score for each grade level from each school
student_data_df.groupby(['school_name','grade'])['math_score'].mean().unstack()
# Out:
# grade                       10th       11th       12th        9th
# school_name
# Bailey High School     76.996772  77.515588  76.492218  77.083676
# Cabrera High School    83.154506  82.765560  83.277487  83.094697
# Figueroa High School   76.539974  76.884344  77.151369  76.403037
# Ford High School       77.672316  76.918058  76.179963  77.361345
# Griffin High School    84.229064  83.842105  83.356164  82.044010
# Hernandez High School  77.337408  77.136029  77.186567  77.438495
# Holden High School     83.429825  85.000000  82.855422  83.787402
# Huang High School      75.908735  76.446602  77.225641  77.027251
# Johnson High School    76.691117  77.491653  76.863248  77.187857
# Pena High School       83.372000  84.328125  84.121547  83.625455
# Rodriguez High School  76.612500  76.395626  77.690748  76.859966
# Shelton High School    82.917411  83.383495  83.778976  83.420755
# Thomas High School     83.087886  83.498795  83.497041  83.590022
# ...

# %%
# student count for Thomas High School ninth graders 
Thomas_9th=student_data_df.loc[(student_data_df['grade']=='9th')&(student_data_df['school_name'] =='Thomas High School')]

# %%
thomas9th,coulmns=Thomas_9th.shape
print(rows)
# Out:
# 39170

# %%
rows,columns=student_data_df.shape
total_number_students=rows
print(total_number_students)
# Out:
# 39170

# %%
total_number_students-thomas9th
# Out:
# 38709

# %%
#student data excluding Thomas high school 9th grade
new_student_data=student_data_df.drop(Thomas_9th.index)

# %%
new_student_data.loc[:,'reading_score'].mean()
# Out:
# 81.85579580976001

# %%
math_score_average=new_student_data.loc[:,'math_score'].mean()
math_score_average
# Out:
# 78.93053295099331

# %%
passing_reading_df=new_student_data.loc[new_student_data['reading_score']>=70]

# %%
passing_math_df=new_student_data.loc[new_student_data['math_score']>=70]

# %%
passing_math_reading = new_student_data[(new_student_data["math_score"] >= 70) & (new_student_data["reading_score"] >= 70)]

# %%
#per school passing math
per_school_passing_math = passing_math_df.groupby(["school_name"]).count()["student_name"]

# %%
#per school passing reading
per_school_passing_reading = passing_reading_df.groupby(["school_name"]).count()["student_name"]

# %%
per_school_passing_math = passing_math_df.count()["student_name"]
per_school_passing_math
# Out:
# 28939

# %%
per_school_passing_reading = passing_reading_df.count()["student_name"]
per_school_passing_reading
# Out:
# 33158

# %%
total_student_count=new_student_data.count()['student_name']

# %%
school_passing_math_percentage = per_school_passing_math/ total_student_count * 100
school_passing_math_percentage
# Out:
# 74.76039164018704

# %%
school_passing_reading_percentage = per_school_passing_reading/ total_student_count * 100
school_passing_reading_percentage
# Out:
# 85.6596657108166

# %%
overall_passing_count = passing_math_reading.count()["student_name"]
overall_passing_count
# Out:
# 25105

# %%
overall_passing_percentage = overall_passing_count/ total_student_count * 100
overall_passing_percentage
# Out:
# 64.85571830840374

# %%
per_school_passing_reading = passing_reading_df.groupby(["school_name"]).count()["student_name"]

# %%
per_school_total_count=student_data_df.groupby(["school_name"]).count()["student_name"]

# %%
per_school_passing_math_percentage = per_school_passing_math / per_school_total_count * 100

# %%
per_school_passing_reading_percentage = per_school_passing_reading / per_school_total_count * 100
per_school_passing_reading_percentage.mean()
# Out:
# 87.37600593620304

# %%
number_of_schools=school_data_df['school_name'].count()
number_of_schools
# Out:
# 15

# %%
number_of_students=student_data_df['student_name'].count()
number_of_students
# Out:
# 39170

# %%
# total budget
Total_budget=school_data_df['budget'].sum()
Total_budget
# Out:
# 24649428

# %%
pd.DataFrame({'Total_schools':[number_of_schools],'Total_students':[number_of_students],'Total_Budget':[Total_budget],'Average_math_score':[math_score_average],'%Passing_Math':[school_passing_math_percentage ],'%Passing_Reading':[school_passing_reading_percentage],'% Oveall_Passing':[overall_passing_percentage]})
# Out:
#    Total_schools  Total_students  Total_Budget  Average_math_score  \
# 0             15           39170      24649428           78.930533
#
#    %Passing_Math  %Passing_Reading  % Oveall_Passing
# 0      74.760392         85.659666         64.855718

# %%
#step 5 ,get the numer of Thomas high school grade 10th_12th students
Thomas_school_students=new_student_data.loc[(new_student_data['school_name'] =='Thomas High School')]

# %%
#thomas high school total count
Total_count_Thomas_School=Thomas_school_students['Student ID'].count()
Total_count_Thomas_School
# Out:
# 1174

# %%
# step 9 percentage of 10th-12th grade students passing math from Thomas High School
Thomas_school_students['math_score'].mean()
# Out:
# 83.35093696763202

# %%
# step 10 percentage of 10th-12th grade students passing reading from Thomas High School
Thomas_school_students['reading_score'].mean()
# Out:
# 83.89608177172062

# %%
# step 6 Thomas_scool_math_passing_data
Thomas_scool_math_passing=Thomas_school_students.loc[Thomas_school_students['math_score']>=70]

# %%
# step 7 Thomas_scool_reading_passing_data
Thomas_scool_reading_passing=Thomas_school_students.loc[Thomas_school_students['reading_score']>=70]

# %%
# step 8 Thomas_scool_overall_passing_data
Thomas_scool_overall_passing=Thomas_school_students.loc[(Thomas_school_students["math_score"] >= 70) & (Thomas_school_students["reading_score"] >= 70)]

# %%
# Thomas high school overall passing count

# %%
#step 9 average passing percentage of math, Thomas high school
percentage_passing_math_Thomas=Thomas_scool_math_passing['math_score'].count()/Total_count_Thomas_School*100
percentage_passing_math_Thomas
# Out:
# 93.18568994889267

# %%
# step 10 average passing percentage of reading, Thomas high school
percentage_passing_reading_Thomas=Thomas_scool_reading_passing['reading_score'].count()/Total_count_Thomas_School*100
percentage_passing_reading_Thomas
# Out:
# 97.01873935264055

# %%
# step 11 overall passing percentage of 10th-12th grade students from Thomas High School
percentage_overall_passing_Thomas=Thomas_scool_overall_passing['Student ID'].count()/Total_count_Thomas_School*100
percentage_overall_passing_Thomas
# Out:
# 90.63032367972743

# %%
#passing math according to schools
per_school_passing_math = passing_math_df.groupby(["school_name"]).count()["student_name"]

# %%
#passing math total schools count
passing_math = passing_math_df.count()["student_name"]
passing_math
# Out:
# 28939

# %%
#passing reading according to schools
per_school_passing_reading = passing_reading_df.groupby(["school_name"]).count()["student_name"]

# %%
#passing reading total count
passing_reading = passing_reading_df.count()["student_name"]
passing_reading
# Out:
# 33158

# %%
#total students count new data(excluding 9th grade Thomas high school)
total_student_count=new_student_data.count()['student_name']
total_student_count
# Out:
# 38709

# %%
#per school passing math percentage
per_school_passing_math_percentage = per_school_passing_math/ per_school_total_count * 100

# %%
#passing math percentage
passing_math_percentage = passing_math/ total_student_count * 100
passing_math_percentage
# Out:
# 74.76039164018704

# %%
#per school passing reading percentage
per_school_passing_reading_percentage = per_school_passing_reading/ per_school_total_count * 100

# %%
#passing reading percentage 
passing_reading_percentage = passing_reading/ total_student_count * 100
passing_reading_percentage
# Out:
# 85.6596657108166

# %%
#overall passing count
overall_passing_count = passing_math_reading.count()["student_name"]
overall_passing_count
# Out:
# 25105

# %%
#overall passing percentage
overall_passing_percentage = overall_passing_count/ total_student_count * 100
overall_passing_percentage
# Out:
# 64.85571830840374

# %%
#total count according to schools
per_school_total_count=new_student_data.groupby(["school_name"]).count()["student_name"]

# %%
#passing math percentage according ton schools
per_school_passing_math_percentage = per_school_passing_math / per_school_total_count * 100

# %%
#passing reading percentage according ton schools
per_school_passing_reading_percentage = per_school_passing_reading / per_school_total_count * 100

# %%
#total number of schools
number_of_schools=school_data_df['school_name'].count()
number_of_schools
# Out:
# 15

# %%
#total number of students
number_of_students=student_data_df['student_name'].count()
number_of_students
# Out:
# 39170

# %%
total_budget = 0

for i in range(len(school_data_df)):
    budget = school_data_df.loc[i, 'budget']
    total_budget += budget
   
total_budget = f'${total_budget:,}'

print(total_budget)
# Out:
# $24,649,428

# %%
#reading score average
reading_score_average=new_student_data.loc[:,'reading_score'].mean()
reading_score_average
# Out:
# 81.85579580976001

# %% [markdown]
# # DISTRICT SUMMARY

# %%
data= [[number_of_schools, number_of_students, total_budget, math_score_average, reading_score_average, passing_math_percentage, passing_reading_percentage,overall_passing_percentage]]
district_summary_df=pd.DataFrame(data,columns=['TotalSchools','TotalStudents', 'TotalBudget', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing'])
district_summary_df
# Out:
#    TotalSchools  TotalStudents  TotalBudget  Average Math Score  \
# 0            15          39170  $24,649,428           78.930533
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0              81.855796       74.760392          85.659666          64.855718

# %%
#school summary dataframe

# %%
# Determine the school type.
per_school_types = school_data_df.set_index(["school_name"])["type"]
per_school_types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# Add the per_school_types into a DataFrame for testing.
df = pd.DataFrame(per_school_types)
df
# Out:
#                            type
# school_name
# Huang High School      District
# Figueroa High School   District
# Shelton High School     Charter
# Hernandez High School  District
# Griffin High School     Charter
# Wilson High School      Charter
# Cabrera High School     Charter
# Bailey High School     District
# Holden High School      Charter
# Pena High School        Charter
# Wright High School      Charter
# Rodriguez High School  District
# Johnson High School    District
# Ford High School       District
# Thomas High School      Charter

# %%
# Calculate the total student count.
per_school_counts = school_data_df["size"]

# %%
# Calculate the total student count.
per_school_counts = school_data_df.set_index(["school_name"])["size"]

# %%
# Calculate the total student count.
per_school_counts = student_data_df["school_name"].value_counts()

# %%
# Calculate the total school budget.
per_school_budget = school_data_df.set_index(["school_name"])["budget"]

# %%
# Calculate the per capita spending.
per_school_capita = per_school_budget / per_school_counts

# %%
# Calculate the math scores.
student_school_math = student_data_df.set_index(["school_name"])["math_score"]

# %%
# per school math averages
per_school_math_averages = student_data_df.groupby(["school_name"])['math_score'].mean()

# %%
# per school reading averages
per_school_reading_averages = student_data_df.groupby(["school_name"])['reading_score'].mean()

# %%
#passing math according to schools
per_school_passing_math = passing_math_df.groupby(["school_name"]).count()["student_name"]

# %%
#passing reading according to schools
per_school_passing_reading = passing_reading_df.groupby(["school_name"]).count()["student_name"]

# %%
# Calculate the students who passed both math and reading.
passing_math_reading = student_data_df[(student_data_df["math_score"] >= 70) & (student_data_df["reading_score"] >= 70)]

# %%
 #Calculate the number of students who passed both math and reading.
per_passing_math_reading = passing_math_reading.groupby(["school_name"])['Student ID'].count()

# %%
# Calculate the overall passing percentage.
per_overall_passing_percentage = per_passing_math_reading / per_school_counts * 100

# %% [markdown]
# # school Summary

# %%
# Adding a list of values with keys to create a new DataFrame.

per_school_summary_df = pd.DataFrame({
             "School Type": per_school_types,
             "Total Students": per_school_counts,
             "Total School Budget": per_school_budget,
             "Per Student Budget": per_school_capita,
             "Average Math Score": per_school_math_averages,
           "Average Reading Score": per_school_reading_averages,
           "% Passing Math": per_school_passing_math_percentage,
           "% Passing Reading":per_school_passing_reading_percentage,
           "% Overall Passing": per_overall_passing_percentage})
per_school_summary_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
per_school_summary_df.loc['Thomas High School','% Passing Math']=percentage_passing_math_Thomas
per_school_summary_df.loc['Thomas High School','% Passing Math']
# Out:
# 93.18568994889267

# %%
per_school_summary_df.loc['Thomas High School','% Passing Reading']=percentage_passing_reading_Thomas
per_school_summary_df.loc['Thomas High School','% Passing Reading']
# Out:
# 97.01873935264055

# %%
per_school_summary_df.loc['Thomas High School','% Overall Passing']=percentage_overall_passing_Thomas
per_school_summary_df.loc['Thomas High School','% Overall Passing']
# Out:
# 90.63032367972743

# %% [markdown]
# # Thomas High School DataFrame

# %%
#Thomas high school DataFrame
pd.DataFrame(per_school_summary_df.loc['Thomas High School']).T
# Out:
#                    School Type Total Students Total School Budget  \
# Thomas High School     Charter           1635             1043130
#
#                    Per Student Budget Average Math Score  \
# Thomas High School              638.0          83.418349
#
#                    Average Reading Score % Passing Math % Passing Reading  \
# Thomas High School              83.84893       93.18569         97.018739
#
#                    % Overall Passing
# Thomas High School         90.630324

# %% [markdown]
# ### Top 5 performing schools, based on the overall passing rate

# %%
per_school_summary_df.sort_values('% Overall Passing',ascending=False).head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %% [markdown]
# ### The bottom 5 performing schools, based on the overall passing rate

# %%
per_school_summary_df.sort_values('% Overall Passing').head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %% [markdown]
# ### The average math score for each grade level from each school

# %%
pd.DataFrame(new_student_data.groupby(['school_name','grade'])['math_score'].mean()).unstack()
# Out:
#                       math_score
# grade                       10th       11th       12th        9th
# school_name
# Bailey High School     76.996772  77.515588  76.492218  77.083676
# Cabrera High School    83.154506  82.765560  83.277487  83.094697
# Figueroa High School   76.539974  76.884344  77.151369  76.403037
# Ford High School       77.672316  76.918058  76.179963  77.361345
# Griffin High School    84.229064  83.842105  83.356164  82.044010
# Hernandez High School  77.337408  77.136029  77.186567  77.438495
# Holden High School     83.429825  85.000000  82.855422  83.787402
# Huang High School      75.908735  76.446602  77.225641  77.027251
# Johnson High School    76.691117  77.491653  76.863248  77.187857
# Pena High School       83.372000  84.328125  84.121547  83.625455
# Rodriguez High School  76.612500  76.395626  77.690748  76.859966
# Shelton High School    82.917411  83.383495  83.778976  83.420755
# ...

# %% [markdown]
# ### The average reading score for each grade level from each school

# %%
pd.DataFrame(new_student_data.groupby(['school_name','grade'])['reading_score'].mean()).unstack()
# Out:
#                       reading_score
# grade                          10th       11th       12th        9th
# school_name
# Bailey High School        80.907183  80.945643  80.912451  81.303155
# Cabrera High School       84.253219  83.788382  84.287958  83.676136
# Figueroa High School      81.408912  80.640339  81.384863  81.198598
# Ford High School          81.262712  80.403642  80.662338  80.632653
# Griffin High School       83.706897  84.288089  84.013699  83.369193
# Hernandez High School     80.660147  81.396140  80.857143  80.866860
# Holden High School        83.324561  83.815534  84.698795  83.677165
# Huang High School         81.512386  81.417476  80.305983  81.290284
# Johnson High School       80.773431  80.616027  81.227564  81.260714
# Pena High School          83.612000  84.335938  84.591160  83.807273
# Rodriguez High School     80.629808  80.864811  80.376426  80.993127
# Shelton High School       83.441964  84.373786  82.781671  84.122642
# ...

# %% [markdown]
# ### The scores by school spending per student

# %%
per_school_summary_df.sort_values(by=['Per Student Budget'],ascending=False)
# Out:
#                       School Type  Total Students  Total School Budget  \
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
# Ford High School         District            2739              1763916
# Figueroa High School     District            2949              1884411
# Thomas High School        Charter            1635              1043130
# Rodriguez High School    District            3999              2547363
# Bailey High School       District            4976              3124928
# Griffin High School       Charter            1468               917500
# Pena High School          Charter             962               585858
# Shelton High School       Charter            1761              1056600
# Wright High School        Charter            1800              1049400
# ...

# %%
per_school_summary_df.sort_values(by=['Per Student Budget'],ascending=False)[['Per Student Budget','% Overall Passing']]
# Out:
#                        Per Student Budget  % Overall Passing
# Huang High School                   655.0          53.513884
# Hernandez High School               652.0          53.527508
# Johnson High School                 650.0          53.539172
# Ford High School                    644.0          54.289887
# Figueroa High School                639.0          53.204476
# Thomas High School                  638.0          90.630324
# Rodriguez High School               637.0          52.988247
# Bailey High School                  628.0          54.642283
# Griffin High School                 625.0          90.599455
# Pena High School                    609.0          90.540541
# Shelton High School                 600.0          89.892107
# Wright High School                  583.0          90.333333
# Cabrera High School                 582.0          91.334769
# Holden High School                  581.0          89.227166
# ...

# %% [markdown]
# ### The scores by school size

# %%
per_school_summary_df.sort_values(by=['Total Students'],ascending=False)
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Johnson High School      District            4761              3094650
# Hernandez High School    District            4635              3022020
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Ford High School         District            2739              1763916
# Wilson High School        Charter            2283              1319574
# Cabrera High School       Charter            1858              1081356
# Wright High School        Charter            1800              1049400
# Shelton High School       Charter            1761              1056600
# Thomas High School        Charter            1635              1043130
# ...

# %%
per_school_summary_df.sort_values(by=['Total Students'],ascending=False)[['Total Students','% Overall Passing']]
# Out:
#                        Total Students  % Overall Passing
# Bailey High School               4976          54.642283
# Johnson High School              4761          53.539172
# Hernandez High School            4635          53.527508
# Rodriguez High School            3999          52.988247
# Figueroa High School             2949          53.204476
# Huang High School                2917          53.513884
# Ford High School                 2739          54.289887
# Wilson High School               2283          90.582567
# Cabrera High School              1858          91.334769
# Wright High School               1800          90.333333
# Shelton High School              1761          89.892107
# Thomas High School               1635          90.630324
# Griffin High School              1468          90.599455
# Pena High School                  962          90.540541
# Holden High School                427          89.227166

# %% [markdown]
# ### The scores by school type

# %%
per_school_summary_df.groupby('School Type').mean()
# Out:
#              Total Students  Total School Budget  Per Student Budget  \
# School Type
# Charter         1524.250000         9.126881e+05          599.500000
# District        3853.714286         2.478275e+06          643.571429
#
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.610020
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.550223          90.392533
# District             80.799062          53.672208

# %%
per_school_summary_df.sort_values(by=['School Type'])
# Out:
#                       School Type  Total Students  Total School Budget  \
# Cabrera High School       Charter            1858              1081356
# Griffin High School       Charter            1468               917500
# Holden High School        Charter             427               248087
# Pena High School          Charter             962               585858
# Shelton High School       Charter            1761              1056600
# Thomas High School        Charter            1635              1043130
# Wilson High School        Charter            2283              1319574
# Wright High School        Charter            1800              1049400
# Bailey High School       District            4976              3124928
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Hernandez High School    District            4635              3022020
# ...
